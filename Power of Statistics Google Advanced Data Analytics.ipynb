# %%
# Compute Descriptive Statistics with pthon

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
education_districtwise = pd.read_csv('education_districtwise.csv')
education_districtwise
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 0     DISTRICT32   STATE1      13       391       104    875564.0       66.92
# 1    DISTRICT649   STATE1      18       678       144   1015503.0       66.93
# 2    DISTRICT229   STATE1       8        94        65   1269751.0       71.21
# 3    DISTRICT259   STATE1      13       523       104    735753.0       57.98
# 4    DISTRICT486   STATE1       8       359        64    570060.0       65.00
# ..           ...      ...     ...       ...       ...         ...         ...
# 675  DISTRICT522  STATE29      37       876       137   5296396.0       78.05
# 676  DISTRICT498  STATE29      64      1458       230   4042191.0       56.06
# 677  DISTRICT343  STATE29      59      1117       216   3483648.0       65.05
# 678  DISTRICT130  STATE29      51       993       211   3522644.0       66.16
# 679  DISTRICT341  STATE29      41       783       185   2798214.0       65.46
#
# [680 rows x 7 columns]

# %%
education_districtwise['OVERALL_LI'].describe()
# Out:
# count    634.000000
# mean      73.395189
# std       10.098460
# min       37.220000
# 25%       66.437500
# 50%       73.490000
# 75%       80.815000
# max       98.760000
# Name: OVERALL_LI, dtype: float64

# %%
education_districtwise['STATNAME'].describe()
# Out:
# count         680
# unique         36
# top       STATE21
# freq           75
# Name: STATNAME, dtype: object

# %%
range_overall_li = education_districtwise['OVERALL_LI'].max() - education_districtwise['OVERALL_LI'].min()
range_overall_li
# Out:
# 61.540000000000006

# %%
# Explore Descriptive Statistics

# %%
# Import relevant Python libraries.

### YOUR CODE HERE ###

import pandas as pd
import numpy as np

# %%
# Load data from the .csv file into a DataFrame and save in a variable.

### YOUR CODE HERE

epa_data = pd.read_csv("c4_epa_air_quality.csv", index_col = 0)
epa_data
# Out:
#      date_local            state_name           county_name      city_name  \
# 0    2018-01-01               Arizona              Maricopa        Buckeye
# 1    2018-01-01                  Ohio               Belmont      Shadyside
# 2    2018-01-01               Wyoming                 Teton  Not in a city
# 3    2018-01-01          Pennsylvania          Philadelphia   Philadelphia
# 4    2018-01-01                  Iowa                  Polk     Des Moines
# ..          ...                   ...                   ...            ...
# 255  2018-01-01  District Of Columbia  District of Columbia     Washington
# 256  2018-01-01             Wisconsin                 Dodge       Kekoskee
# 257  2018-01-01              Kentucky             Jefferson     Louisville
# 258  2018-01-01              Nebraska               Douglas          Omaha
# 259  2018-01-01        North Carolina                  Wake  Not in a city
#
#                                        local_site_name   parameter_name  \
# 0                                              BUCKEYE  Carbon monoxide
# 1                                            Shadyside  Carbon monoxide
# 2    Yellowstone National Park - Old Faithful Snow ...  Carbon monoxide
# 3                               North East Waste (NEW)  Carbon monoxide
# 4                                            CARPENTER  Carbon monoxide
# ..                                                 ...              ...
# 255                                          Near Road  Carbon monoxide
# 256                              HORICON WILDLIFE AREA  Carbon monoxide
# 257                                       CANNONS LANE  Carbon monoxide
# 258                                                NaN  Carbon monoxide
# 259                                         Triple Oak  Carbon monoxide
#
#       units_of_measure  arithmetic_mean  aqi
# 0    Parts per million         0.473684    7
# 1    Parts per million         0.263158    5
# 2    Parts per million         0.111111    2
# 3    Parts per million         0.300000    3
# 4    Parts per million         0.215789    3
# ..                 ...              ...  ...
# 255  Parts per million         0.244444    3
# 256  Parts per million         0.200000    2
# 257  Parts per million         0.163158    2
# 258  Parts per million         0.421053    9
# 259  Parts per million         0.188889    2
#
# [260 rows x 9 columns]

# %%
# Display first 10 rows of the data.

### YOUR CODE HERE

epa_data.head(10)
# Out:
#    date_local    state_name   county_name      city_name  \
# 0  2018-01-01       Arizona      Maricopa        Buckeye
# 1  2018-01-01          Ohio       Belmont      Shadyside
# 2  2018-01-01       Wyoming         Teton  Not in a city
# 3  2018-01-01  Pennsylvania  Philadelphia   Philadelphia
# 4  2018-01-01          Iowa          Polk     Des Moines
# 5  2018-01-01        Hawaii      Honolulu  Not in a city
# 6  2018-01-01        Hawaii      Honolulu  Not in a city
# 7  2018-01-01  Pennsylvania          Erie           Erie
# 8  2018-01-01        Hawaii      Honolulu       Honolulu
# 9  2018-01-01      Colorado       Larimer   Fort Collins
#
#                                      local_site_name   parameter_name  \
# 0                                            BUCKEYE  Carbon monoxide
# 1                                          Shadyside  Carbon monoxide
# 2  Yellowstone National Park - Old Faithful Snow ...  Carbon monoxide
# 3                             North East Waste (NEW)  Carbon monoxide
# 4                                          CARPENTER  Carbon monoxide
# 5                                            Kapolei  Carbon monoxide
# 6                                            Kapolei  Carbon monoxide
# 7                                                NaN  Carbon monoxide
# 8                                           Honolulu  Carbon monoxide
# 9                      Fort Collins - CSU - S. Mason  Carbon monoxide
#
#     units_of_measure  arithmetic_mean  aqi
# 0  Parts per million         0.473684    7
# 1  Parts per million         0.263158    5
# 2  Parts per million         0.111111    2
# 3  Parts per million         0.300000    3
# 4  Parts per million         0.215789    3
# 5  Parts per million         0.994737   14
# 6  Parts per million         0.200000    2
# 7  Parts per million         0.200000    2
# 8  Parts per million         0.400000    5
# 9  Parts per million         0.300000    6

# %%
# Get descriptive stats.

### YOUR CODE HERE

epa_data.describe()
# Out:
#        arithmetic_mean         aqi
# count       260.000000  260.000000
# mean          0.403169    6.757692
# std           0.317902    7.061707
# min           0.000000    0.000000
# 25%           0.200000    2.000000
# 50%           0.276315    5.000000
# 75%           0.516009    9.000000
# max           1.921053   50.000000

# %%
# Get descriptive stats about the states in the data.

### YOUR CODE HERE

epa_data["state_name"].describe()
# Out:
# count            260
# unique            52
# top       California
# freq              66
# Name: state_name, dtype: object

# %%
# Compute the mean value from the aqi column.

### YOUR CODE HERE

np.mean(epa_data["aqi"])
# Out:
# 6.757692307692308

# %%
# Compute the median value from the aqi column.

### YOUR CODE HERE

np.median(epa_data["aqi"])
# Out:
# 5.0

# %%
# Identify the minimum value from the aqi column.

### YOUR CODE HERE

np.min(epa_data["aqi"])
# Out:
# 0

# %%
# Identify the maximum value from the aqi column.

### YOUR CODE HERE

np.max(epa_data["aqi"])
# Out:
# 50

# %%
# Compute the standard deviation for the aqi column.

### YOUR CODE HERE

np.std(epa_data["aqi"], ddof=1)
# Out:
# 7.0617066788207215

# %%
# Working with probability distribution in Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
education_districtwise = pd.read_csv('education_districtwise.csv')
education_districtwise = education_districtwise.dropna()
education_districtwise
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 0     DISTRICT32   STATE1      13       391       104    875564.0       66.92
# 1    DISTRICT649   STATE1      18       678       144   1015503.0       66.93
# 2    DISTRICT229   STATE1       8        94        65   1269751.0       71.21
# 3    DISTRICT259   STATE1      13       523       104    735753.0       57.98
# 4    DISTRICT486   STATE1       8       359        64    570060.0       65.00
# ..           ...      ...     ...       ...       ...         ...         ...
# 675  DISTRICT522  STATE29      37       876       137   5296396.0       78.05
# 676  DISTRICT498  STATE29      64      1458       230   4042191.0       56.06
# 677  DISTRICT343  STATE29      59      1117       216   3483648.0       65.05
# 678  DISTRICT130  STATE29      51       993       211   3522644.0       66.16
# 679  DISTRICT341  STATE29      41       783       185   2798214.0       65.46
#
# [634 rows x 7 columns]

# %%
education_districtwise['OVERALL_LI'].hist()
# Out:
# <Axes: >

# %%
mean_overall_li = education_districtwise['OVERALL_LI'].mean()
mean_overall_li
# Out:
# 73.39518927444796

# %%
std_overall_li = education_districtwise['OVERALL_LI'].std()
std_overall_li
# Out:
# 10.098460413782469

# %%
lower_limit = mean_overall_li - 1 * std_overall_li
upper_limit = mean_overall_li + 1 * std_overall_li
((education_districtwise['OVERALL_LI'] >= lower_limit) & (education_districtwise['OVERALL_LI'] <= upper_limit)).mean()
# Out:
# 0.6640378548895899

# %%
lower_limit = mean_overall_li - 2 * std_overall_li
upper_limit = mean_overall_li + 2 * std_overall_li
((education_districtwise['OVERALL_LI'] >= lower_limit) & (education_districtwise['OVERALL_LI'] <= upper_limit)).mean()
# Out:
# 0.9542586750788643

# %%
education_districtwise['Z_SCORE'] = stats.zscore(education_districtwise['OVERALL_LI'])
education_districtwise
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI  \
# 0     DISTRICT32   STATE1      13       391       104    875564.0       66.92
# 1    DISTRICT649   STATE1      18       678       144   1015503.0       66.93
# 2    DISTRICT229   STATE1       8        94        65   1269751.0       71.21
# 3    DISTRICT259   STATE1      13       523       104    735753.0       57.98
# 4    DISTRICT486   STATE1       8       359        64    570060.0       65.00
# ..           ...      ...     ...       ...       ...         ...         ...
# 675  DISTRICT522  STATE29      37       876       137   5296396.0       78.05
# 676  DISTRICT498  STATE29      64      1458       230   4042191.0       56.06
# 677  DISTRICT343  STATE29      59      1117       216   3483648.0       65.05
# 678  DISTRICT130  STATE29      51       993       211   3522644.0       66.16
# 679  DISTRICT341  STATE29      41       783       185   2798214.0       65.46
#
#       Z_SCORE
# 0   -0.641712
# 1   -0.640721
# 2   -0.216559
# 3   -1.527694
# 4   -0.831990
# ..        ...
# 675  0.461307
# 676 -1.717972
# 677 -0.827035
# 678 -0.717030
# 679 -0.786403
#
# [634 rows x 8 columns]

# %%
education_districtwise[(education_districtwise['Z_SCORE'] > 3) | (education_districtwise['Z_SCORE'] < -3)]
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI  \
# 434  DISTRICT461  STATE31       4       360        53    532791.0       42.67
# 494  DISTRICT429  STATE22       6       612        62    728677.0       37.22
#
#       Z_SCORE
# 434 -3.044964
# 494 -3.585076

# %%
#Sampling with Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %%
education_districtwise = pd.read_csv('education_districtwise.csv')
education_districtwise = education_districtwise.dropna()
education_districtwise
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 0     DISTRICT32   STATE1      13       391       104    875564.0       66.92
# 1    DISTRICT649   STATE1      18       678       144   1015503.0       66.93
# 2    DISTRICT229   STATE1       8        94        65   1269751.0       71.21
# 3    DISTRICT259   STATE1      13       523       104    735753.0       57.98
# 4    DISTRICT486   STATE1       8       359        64    570060.0       65.00
# ..           ...      ...     ...       ...       ...         ...         ...
# 675  DISTRICT522  STATE29      37       876       137   5296396.0       78.05
# 676  DISTRICT498  STATE29      64      1458       230   4042191.0       56.06
# 677  DISTRICT343  STATE29      59      1117       216   3483648.0       65.05
# 678  DISTRICT130  STATE29      51       993       211   3522644.0       66.16
# 679  DISTRICT341  STATE29      41       783       185   2798214.0       65.46
#
# [634 rows x 7 columns]

# %%
# Stimulate Random Sampling

# %%
sampled_data = education_districtwise.sample(n=50, replace=True, random_state=31208)
sampled_data
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 661  DISTRICT528   STATE6       9       112        89   1863174.0       92.14
# 216  DISTRICT291  STATE28      14      1188       165   3273127.0       52.49
# 367   DISTRICT66  STATE23      12      1169       116   1042304.0       62.14
# 254  DISTRICT458   STATE3       3       157        19     82839.0       76.33
# 286  DISTRICT636  STATE35       3       187        44    514683.0       86.70
# 369  DISTRICT512  STATE23       6       589        30    717169.0       68.35
# 258  DISTRICT156   STATE3       6        80         9     35289.0       59.94
# 10   DISTRICT412   STATE1      11       187        95    476820.0       68.69
# 512  DISTRICT277   STATE9      10       558       179   2298934.0       84.31
# 144  DISTRICT133  STATE21      14      1672       136   3673849.0       69.61
# 325    DISTRICT1  STATE33       4       534        98    957853.0       69.37
# 227  DISTRICT159  STATE28      18       870       134   2954367.0       66.23
# 86   DISTRICT667  STATE25       5       396        75    896129.0       82.23
# 425  DISTRICT144  STATE31       7      1064       108   2662077.0       71.59
# 260  DISTRICT305   STATE3       2        62         6    145538.0       69.88
# 281  DISTRICT385  STATE35       6       531        30    354972.0       75.00
# 262  DISTRICT552   STATE3       3       103         4    111997.0       52.23
# 253  DISTRICT168   STATE3       5       312        16    176385.0       82.14
# 301  DISTRICT551  STATE14       9       103        63    693281.0       88.29
# 356  DISTRICT494  STATE34      25      2179       223   3596292.0       70.95
# 165  DISTRICT196  STATE21      10      1354       119   1795092.0       77.52
# 565  DISTRICT308  STATE17       8       721       144    848868.0       86.54
# 388  DISTRICT281  STATE23       6       392        58    949159.0       73.92
# 461  DISTRICT619  STATE22       5       859        57   1064989.0       68.36
# 384  DISTRICT455  STATE23       9      1217        55   1063458.0       68.85
# 590   DISTRICT70  STATE20       7       427        84   1846993.0       80.30
# 343  DISTRICT354  STATE33       2       192        46   1260419.0       88.66
# 539  DISTRICT440  STATE17      15      1465       167   2887826.0       88.23
# 459  DISTRICT431  STATE22       9      1778       143   2363744.0       73.42
# 667  DISTRICT123  STATE11       3        80        16    237586.0       88.49
# 387  DISTRICT231  STATE23       6       657        63    530299.0       64.51
# 306   DISTRICT37   STATE4       7      1083        92    642923.0       68.38
# 213  DISTRICT347  STATE28      11       623        94   2228397.0       59.65
# 97    DISTRICT22   STATE2       7       182         7   2531583.0       87.12
# 78   DISTRICT247  STATE25       7       314        60   1332042.0       72.73
# 394  DISTRICT640  STATE24      17      1857       191   1802777.0       69.00
# 184  DISTRICT596  STATE21      11      1281       108   2149066.0       51.76
# 147  DISTRICT335  STATE21      17      1945       138   4380793.0       69.44
# 542  DISTRICT489  STATE17       7       749        63   1198810.0       85.14
# 105  DISTRICT157  STATE13      14      1994       508   3671999.0       71.68
# 254  DISTRICT458   STATE3       3       157        19     82839.0       76.33
# 109  DISTRICT158  STATE13       6       769       211   1338114.0       66.19
# 609   DISTRICT17  STATE20       4       359        59   9588910.0       88.48
# 53   DISTRICT126  STATE26       3       197        21    596294.0       68.90
# 81    DISTRICT45  STATE25       9       351       130   1742815.0       73.24
# 516  DISTRICT300   STATE9       5       651        84    590379.0       73.29
# 641  DISTRICT484   STATE6      15       333        83   1721179.0       74.92
# 650  DISTRICT145   STATE6      11       489       100   1614069.0       84.09
# 70    DISTRICT99  STATE25       4       279        43    558890.0       83.44
# 163  DISTRICT366  STATE21       9      1330        86   1579160.0       79.99

# %%
# Computing the sample mean
estimate1 = sampled_data['OVERALL_LI'].mean()
estimate1
# Out:
# 74.22359999999999

# %%
# Central Limit Theorem
# Computing the sample mean of 10,000 samples

# %%
estimate_list = []
for i in range(10000):
    estimate_list.append(education_districtwise['OVERALL_LI'].sample(n=50, replace=True).mean())
estimate_df = pd.DataFrame(data={'estimate': estimate_list})
estimate_df
# Out:
#       estimate
# 0      73.1602
# 1      75.0738
# 2      71.1364
# 3      74.9728
# 4      74.7366
# ...        ...
# 9995   73.8262
# 9996   74.4808
# 9997   73.1058
# 9998   72.5716
# 9999   73.1056
#
# [10000 rows x 1 columns]

# %%
mean_sample_means = estimate_df['estimate'].mean()
mean_sample_means
# Out:
# 73.3704168

# %%
# Visualizing the Data

# %%
plt.hist(estimate_df['estimate'], bins=25, density=True, alpha=0.4, label = "histogram of sample means of 10000 random samples")
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100) # generate a grid of 100 values from xmin to xmax.
p = stats.norm.pdf(x, mean_sample_means, stats.tstd(estimate_df['estimate']))
plt.plot(x, p,'k', linewidth=2, label = 'normal curve from central limit theorem')
plt.axvline(x=population_mean, color='g', linestyle = 'solid', label = 'population mean')
plt.axvline(x=estimate1, color='r', linestyle = '--', label = 'sample mean of the first random sample')
plt.axvline(x=mean_sample_means, color='b', linestyle = ':', label = 'mean of sample means of 10000 random samples')
plt.title("Sampling distribution of sample mean")
plt.xlabel('sample mean')
plt.ylabel('density')
plt.legend(bbox_to_anchor=(1.04,1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       4 p = stats.norm.pdf(x, mean_sample_means, stats.tstd(estimate_df['estimate']))
#       5 plt.plot(x, p,'k', linewidth=2, label = 'normal curve from central limit theorem')
# ----> 6 plt.axvline(x=population_mean, color='g', linestyle = 'solid', label = 'population mean')
#       7 plt.axvline(x=estimate1, color='r', linestyle = '--', label = 'sample mean of the first random sample')
#       8 plt.axvline(x=mean_sample_means, color='b', linestyle = ':', label = 'mean of sample means of 10000 random samples')
#
# NameError: name 'population_mean' is not defined

# %%
# Working with Confidence Interval in Python

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
education_districtwise = pd.read_csv("education_districtwise.csv")
education_districtwise = education_districtwise.dropna()
education_districtwise
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 0     DISTRICT32   STATE1      13       391       104    875564.0       66.92
# 1    DISTRICT649   STATE1      18       678       144   1015503.0       66.93
# 2    DISTRICT229   STATE1       8        94        65   1269751.0       71.21
# 3    DISTRICT259   STATE1      13       523       104    735753.0       57.98
# 4    DISTRICT486   STATE1       8       359        64    570060.0       65.00
# ..           ...      ...     ...       ...       ...         ...         ...
# 675  DISTRICT522  STATE29      37       876       137   5296396.0       78.05
# 676  DISTRICT498  STATE29      64      1458       230   4042191.0       56.06
# 677  DISTRICT343  STATE29      59      1117       216   3483648.0       65.05
# 678  DISTRICT130  STATE29      51       993       211   3522644.0       66.16
# 679  DISTRICT341  STATE29      41       783       185   2798214.0       65.46
#
# [634 rows x 7 columns]

# %%
sampled_data = education_districtwise.sample(n=50, replace=True, random_state=31208)
sampled_data
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 661  DISTRICT528   STATE6       9       112        89   1863174.0       92.14
# 216  DISTRICT291  STATE28      14      1188       165   3273127.0       52.49
# 367   DISTRICT66  STATE23      12      1169       116   1042304.0       62.14
# 254  DISTRICT458   STATE3       3       157        19     82839.0       76.33
# 286  DISTRICT636  STATE35       3       187        44    514683.0       86.70
# 369  DISTRICT512  STATE23       6       589        30    717169.0       68.35
# 258  DISTRICT156   STATE3       6        80         9     35289.0       59.94
# 10   DISTRICT412   STATE1      11       187        95    476820.0       68.69
# 512  DISTRICT277   STATE9      10       558       179   2298934.0       84.31
# 144  DISTRICT133  STATE21      14      1672       136   3673849.0       69.61
# 325    DISTRICT1  STATE33       4       534        98    957853.0       69.37
# 227  DISTRICT159  STATE28      18       870       134   2954367.0       66.23
# 86   DISTRICT667  STATE25       5       396        75    896129.0       82.23
# 425  DISTRICT144  STATE31       7      1064       108   2662077.0       71.59
# 260  DISTRICT305   STATE3       2        62         6    145538.0       69.88
# 281  DISTRICT385  STATE35       6       531        30    354972.0       75.00
# 262  DISTRICT552   STATE3       3       103         4    111997.0       52.23
# 253  DISTRICT168   STATE3       5       312        16    176385.0       82.14
# 301  DISTRICT551  STATE14       9       103        63    693281.0       88.29
# 356  DISTRICT494  STATE34      25      2179       223   3596292.0       70.95
# 165  DISTRICT196  STATE21      10      1354       119   1795092.0       77.52
# 565  DISTRICT308  STATE17       8       721       144    848868.0       86.54
# 388  DISTRICT281  STATE23       6       392        58    949159.0       73.92
# 461  DISTRICT619  STATE22       5       859        57   1064989.0       68.36
# 384  DISTRICT455  STATE23       9      1217        55   1063458.0       68.85
# 590   DISTRICT70  STATE20       7       427        84   1846993.0       80.30
# 343  DISTRICT354  STATE33       2       192        46   1260419.0       88.66
# 539  DISTRICT440  STATE17      15      1465       167   2887826.0       88.23
# 459  DISTRICT431  STATE22       9      1778       143   2363744.0       73.42
# 667  DISTRICT123  STATE11       3        80        16    237586.0       88.49
# 387  DISTRICT231  STATE23       6       657        63    530299.0       64.51
# 306   DISTRICT37   STATE4       7      1083        92    642923.0       68.38
# 213  DISTRICT347  STATE28      11       623        94   2228397.0       59.65
# 97    DISTRICT22   STATE2       7       182         7   2531583.0       87.12
# 78   DISTRICT247  STATE25       7       314        60   1332042.0       72.73
# 394  DISTRICT640  STATE24      17      1857       191   1802777.0       69.00
# 184  DISTRICT596  STATE21      11      1281       108   2149066.0       51.76
# 147  DISTRICT335  STATE21      17      1945       138   4380793.0       69.44
# 542  DISTRICT489  STATE17       7       749        63   1198810.0       85.14
# 105  DISTRICT157  STATE13      14      1994       508   3671999.0       71.68
# 254  DISTRICT458   STATE3       3       157        19     82839.0       76.33
# 109  DISTRICT158  STATE13       6       769       211   1338114.0       66.19
# 609   DISTRICT17  STATE20       4       359        59   9588910.0       88.48
# 53   DISTRICT126  STATE26       3       197        21    596294.0       68.90
# 81    DISTRICT45  STATE25       9       351       130   1742815.0       73.24
# 516  DISTRICT300   STATE9       5       651        84    590379.0       73.29
# 641  DISTRICT484   STATE6      15       333        83   1721179.0       74.92
# 650  DISTRICT145   STATE6      11       489       100   1614069.0       84.09
# 70    DISTRICT99  STATE25       4       279        43    558890.0       83.44
# 163  DISTRICT366  STATE21       9      1330        86   1579160.0       79.99

# %%
sample_mean = sampled_data['OVERALL_LI'].mean()
sample_mean
# Out:
# 74.22359999999999

# %%
estimated_standard_error = sampled_data['OVERALL_LI'].std() / np.sqrt(sampled_data.shape[0])
estimated_standard_error
# Out:
# 1.4292043386558317

# %%
# Calculating the confidence interval of 95%
confidence_interval = stats.norm.interval(confidence=0.95, loc=sample_mean, scale=estimated_standard_error)
print(confidence_interval)
# Out:
# (71.42241096968617, 77.02478903031381)

# %%
confidence_interval = stats.norm.interval(confidence=0.99, loc=sample_mean, scale=estimated_standard_error)
print(confidence_interval)
# Out:
# (70.54221358373107, 77.90498641626891)

# %%
import pandas as pd
from scipy import stats

# %%
# Using Python to conduct Hypothesis test

# %%
education_districtwise = pd.read_csv("education_districtwise.csv")
education_districtwise = education_districtwise.dropna()
education_districtwise
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 0     DISTRICT32   STATE1      13       391       104    875564.0       66.92
# 1    DISTRICT649   STATE1      18       678       144   1015503.0       66.93
# 2    DISTRICT229   STATE1       8        94        65   1269751.0       71.21
# 3    DISTRICT259   STATE1      13       523       104    735753.0       57.98
# 4    DISTRICT486   STATE1       8       359        64    570060.0       65.00
# ..           ...      ...     ...       ...       ...         ...         ...
# 675  DISTRICT522  STATE29      37       876       137   5296396.0       78.05
# 676  DISTRICT498  STATE29      64      1458       230   4042191.0       56.06
# 677  DISTRICT343  STATE29      59      1117       216   3483648.0       65.05
# 678  DISTRICT130  STATE29      51       993       211   3522644.0       66.16
# 679  DISTRICT341  STATE29      41       783       185   2798214.0       65.46
#
# [634 rows x 7 columns]

# %%
state21 = education_districtwise[education_districtwise['STATNAME'] == "STATE21"]
state21
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 133  DISTRICT607  STATE21      14      1357       127   3464228.0       72.03
# 134   DISTRICT50  STATE21      12       594        86   4138605.0       70.11
# 135   DISTRICT61  STATE21      16      1919       159   3683896.0       70.43
# 136  DISTRICT191  STATE21      10      1141        69   4773138.0       58.67
# 137  DISTRICT328  STATE21       7      1116        85   2335398.0       55.08
# ..           ...      ...     ...       ...       ...         ...         ...
# 199  DISTRICT587  STATE21      10      1331       119   3682194.0       77.05
# 201  DISTRICT504  STATE21      13      1469       106   2494533.0       70.38
# 202   DISTRICT88  STATE21       8      1033        67   1862612.0       66.18
# 203  DISTRICT427  STATE21       7       805        80   1554203.0       71.10
# 204  DISTRICT658  STATE21      10       886        80   1438156.0       62.30
#
# [71 rows x 7 columns]

# %%
state28 = education_districtwise[education_districtwise['STATNAME'] == "STATE28"]
state28
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 208  DISTRICT495  STATE28      18      1210       193   3922780.0       58.06
# 209  DISTRICT208  STATE28      27      1534       251   5082868.0       58.26
# 210  DISTRICT618  STATE28       5       183        34    656916.0       56.00
# 211  DISTRICT554  STATE28      17       852       169   3419622.0       53.53
# 212  DISTRICT642  STATE28      21      1102       241   4476044.0       60.90
# 213  DISTRICT347  STATE28      11       623        94   2228397.0       59.65
# 214    DISTRICT4  STATE28       9       990       140   2806200.0       55.10
# 215   DISTRICT52  STATE28       7       978       131   1690948.0       57.04
# 216  DISTRICT291  STATE28      14      1188       165   3273127.0       52.49
# 217  DISTRICT266  STATE28      16      1621       173   3068149.0       53.56
# 218  DISTRICT227  STATE28      13       404       126   1994618.0       53.78
# 219  DISTRICT459  STATE28      10       651       107   1897102.0       54.57
# 220  DISTRICT569  STATE28      19      1168       191   3921971.0       58.26
# 221  DISTRICT501  STATE28      16      1828       258   4778610.0       65.68
# 222  DISTRICT663  STATE28      14      1358       120   2558037.0       67.04
# 223  DISTRICT330  STATE28      19      1405       171   3318176.0       71.59
# 224  DISTRICT290  STATE28      20      1564       178   3943098.0       68.57
# 225  DISTRICT295  STATE28      16      1187       182   3495249.0       68.56
# 226  DISTRICT638  STATE28      20      1138       182   4254782.0       63.81
# 227  DISTRICT159  STATE28      18       870       134   2954367.0       66.23
# 228  DISTRICT251  STATE28       7       287        88   1657599.0       60.87
# 229  DISTRICT583  STATE28      17      1394       156   3032226.0       64.96
# 230  DISTRICT109  STATE28      11      1340       178   2029339.0       60.12
# 231  DISTRICT451  STATE28       9       535        78   1359054.0       73.30
# 232  DISTRICT216  STATE28       7       471        61   1000717.0       64.95
# 233   DISTRICT67  STATE28       6       355        43    634927.0       65.96
# 234  DISTRICT517  STATE28      20      1114       189   2872523.0       66.41
# 235  DISTRICT111  STATE28      24      1600       266   5772804.0       72.47
# 236  DISTRICT379  STATE28      14      1204       159   2720155.0       72.79
# 237  DISTRICT151  STATE28      11       767       101   1707643.0       71.77
# 238   DISTRICT64  STATE28      11      1101        73   1626900.0       71.01
# 239  DISTRICT374  STATE28      19      1907       200   2962593.0       75.59
# 240  DISTRICT463  STATE28       7       512        69   1124176.0       68.27
# 241  DISTRICT324  STATE28      11      1690       172   2511243.0       72.77
# 242  DISTRICT285  STATE28      24      2334       252   4379383.0       66.35
# 243  DISTRICT387  STATE28      14       953       132   2216653.0       61.63
# 244   DISTRICT47  STATE28      10      1054       143   1756078.0       62.16
# 245  DISTRICT418  STATE28       5       307        33    699563.0       69.54

# %%
sampled_state21 = state21.sample(n=20, replace = True, random_state=13490)
sampled_state21
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 169  DISTRICT373  STATE21       7       713        49   1218002.0       64.95
# 136  DISTRICT191  STATE21      10      1141        69   4773138.0       58.67
# 193  DISTRICT398  STATE21      23      2618       283   4616509.0       72.69
# 201  DISTRICT504  STATE21      13      1469       106   2494533.0       70.38
# 180   DISTRICT19  STATE21      10      1374       113   2398709.0       74.37
# 164  DISTRICT581  STATE21       8      1133        90   1372287.0       80.25
# 191  DISTRICT199  STATE21      15      1444       145   3560830.0       67.66
# 174  DISTRICT102  STATE21      15      1606       180   2632684.0       68.78
# 194   DISTRICT39  STATE21      10       751       124   2205170.0       75.16
# 154   DISTRICT28  STATE21      17      2185       161   3002376.0       61.61
# 172  DISTRICT553  STATE21       9       487        72   1799541.0       68.11
# 149  DISTRICT456  STATE21      11      1134        74   1761152.0       73.27
# 148  DISTRICT542  STATE21      11      1339       140   2496761.0       74.60
# 198  DISTRICT601  STATE21      10      1189       128   1952713.0       73.86
# 179  DISTRICT574  STATE21      17      1218       143   2468371.0       70.63
# 157  DISTRICT647  STATE21      25      2161       208   4091380.0       68.89
# 166  DISTRICT575  STATE21      20      1091       175   4572951.0       81.31
# 146  DISTRICT368  STATE21      13      1199       123   2541894.0       72.65
# 194   DISTRICT39  STATE21      10       751       124   2205170.0       75.16
# 153  DISTRICT185  STATE21       9      1205        97   2037225.0       63.58

# %%
sampled_state28 = state28.sample(n=20, replace = True, random_state=39103)
sampled_state28
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 214    DISTRICT4  STATE28       9       990       140   2806200.0       55.10
# 239  DISTRICT374  STATE28      19      1907       200   2962593.0       75.59
# 221  DISTRICT501  STATE28      16      1828       258   4778610.0       65.68
# 211  DISTRICT554  STATE28      17       852       169   3419622.0       53.53
# 211  DISTRICT554  STATE28      17       852       169   3419622.0       53.53
# 234  DISTRICT517  STATE28      20      1114       189   2872523.0       66.41
# 239  DISTRICT374  STATE28      19      1907       200   2962593.0       75.59
# 243  DISTRICT387  STATE28      14       953       132   2216653.0       61.63
# 219  DISTRICT459  STATE28      10       651       107   1897102.0       54.57
# 212  DISTRICT642  STATE28      21      1102       241   4476044.0       60.90
# 225  DISTRICT295  STATE28      16      1187       182   3495249.0       68.56
# 229  DISTRICT583  STATE28      17      1394       156   3032226.0       64.96
# 223  DISTRICT330  STATE28      19      1405       171   3318176.0       71.59
# 217  DISTRICT266  STATE28      16      1621       173   3068149.0       53.56
# 226  DISTRICT638  STATE28      20      1138       182   4254782.0       63.81
# 222  DISTRICT663  STATE28      14      1358       120   2558037.0       67.04
# 231  DISTRICT451  STATE28       9       535        78   1359054.0       73.30
# 212  DISTRICT642  STATE28      21      1102       241   4476044.0       60.90
# 235  DISTRICT111  STATE28      24      1600       266   5772804.0       72.47
# 231  DISTRICT451  STATE28       9       535        78   1359054.0       73.30

# %%
# Compute sample mean
sampled_state21['OVERALL_LI'].mean()
# Out:
# 70.82900000000001

# %%
sampled_state28['OVERALL_LI'].mean()
# Out:
# 64.60100000000001

# %%
stats.ttest_ind(a=sampled_state21['OVERALL_LI'], b=sampled_state28['OVERALL_LI'], equal_var=False)
# Out:
# TtestResult(statistic=2.8980444277268735, pvalue=0.006421719142765237, df=35.20796133045557)
